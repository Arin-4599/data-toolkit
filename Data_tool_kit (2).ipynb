# %% [markdown]
# # DATA TOOLKIT
#
# 1. What is NumPy, and why is it widely used in Python?
#    - numpy is a python library used to store data in array formate
#    - we use numpy as import numpy as np
#    - numpy is very fast and made by c language
#    - in numpy we use np.array(), np.asarray(), np.asanyarray()
#
# 2.  How does broadcasting work in NumPy?
#     - Broadcasting is NumPy’s rule‑set for stretching (“broadcasting”) arrays with smaller shapes so they can take part in element‑wise operations without making explicit copies
#
# 3. What is a Pandas DataFrame?
#    - pandas is used to make dataframe by pd.DataFrame() in this dataframe we use index to denote data
#    - like 0-Arin , 1- ayush, in this we can make custom indexes
#
# 4.  Explain the use of the groupby() method in Pandas?
#     - groupby >> splitting the data as per information like peoplr survived in tatinic
#
# 5.  Why is Seaborn preferred for statistical visualizations?
#     - because it has more statistical plots
#     - it has more attractive plots
#     - it is based on matplotlib and it give high level interface for drawing
#     attractive graphic
#
# 6.  What are the differences between NumPy arrays and Python lists?
#     - numpy arrays are store data in array form and like for eg:- array([1,2,3,4,5,6])
#     - but in python list they store data in format like [1,2,3,4,5]
#     - in numpy array all element are of same datatype but in list element can mix datatype
#
# 7.  What is a heatmap, and when should it be used?
#     - A heatmap is a data visualization technique that encodes values as color inside a 2D grid (or sometimes over a geographic/graph surface). Darker, lighter, or otherwise varying hues let the eye spot patterns—highs, lows, clusters—far faster than numbers in a table
#
# 8.  What does the term “vectorized operation” mean in NumPy?
#     - vectorized operation in numpy are high level array expression and loops that handel all expression execute in one go
#
# 9.  How does Matplotlib differ from Plotly?
#     - matplotlib is data visualition techinque which make esay task more easier and hard task possible  it contain scatter plot, line plot, piechart, histogram, area plot
#     - plotly has little bit of tough syntax for eg:- it use fig = go.figure()
#     fig.add_trace()
#
# 10.  What is the significance of hierarchical indexing in Pandas?
#      -  hierarchical indexing is a indexing in which a single index of dataframe have multiple index level
#      - it give selective silcing , easy reshaping
#
# 11.  What is the role of Seaborn’s pairplot() function?
#      - sns.pairplot() it means make scatter plots with respect to all numerical columns
#
# 12.  What is the purpose of the describe() function in Pandas?
#      - it give statistical information about numerical coloumn pd.describe()
#      - it give five point summary i.e:- min, 25%, 50%, 75%, max
#
# 13.  Why is handling missing data important in Pandas?
#      - handling missing data is important because it give incorrect result , failed computation , because real world data is messay that why handling missing data is important
#
# 14.  What are the benefits of using Plotly for data visualization?
#      - plotly chart are fully interactive it give all scatter, line , histogram,
#      barplot
#      - it give flexibility with little code
#      - it support huge varirty of code
#
# 15.  How does NumPy handle multidimensional arrays?
#      - numpy handels multidimension array in form of matrix with rows and coloumn, like 3rows and 5column
#      - eg:- np.array(3,4) it will give multidim array
#
# 16.  What is the role of Bokeh in data visualization?
#      - bokeh is used to create browser based visualization it is mainly good for large data
#      - it bridges the gap between simple static ploting and full blown interactive web dashboard
#
# 17.  Explain the difference between apply() and map() in Pandas?
#      - they are used to transform data
#      - map() = used with pandas serease it do element wise transformation
#      - apply() = use with both serise and dataframe use with row and colouum wise operations
#
# 18.  What are some advanced features of NumPy?
#      - numpy is used for converting data into array by using np.array , np.asarray , asanyarray(),
#      - nunpy is used in boardcasting
#
# 19.  How does Pandas simplify time series analysis?
#      - pandas simplify time series analysis by time indexing and date indexing
#      - by shifting data, logging data
#
# 20.  What is the role of a pivot table in Pandas?
#      - it is used to aggreate data and make data in more readable form
#      - to apply aggreate function
#
# 21.  Why is NumPy’s array slicing faster than Python’s list slicing?
#      - numpy is made by c language and it is very fast thats why slicing is fast
#      - numpy store data in only one form thatswhy slicing is fast
#
# 22.  What are some common use cases for Seaborn
#      - categorical data visulation is comman use case seaborn

# %%
#1.  How do you create a 2D NumPy array and calculate the sum of each row?
import numpy as np
arr = np.asarray([[1,2,3],
            [2,5,6]])
sum_of_rows = np.sum(arr, axis= 1)
print(sum_of_rows)

#2.  Write a Pandas script to find the mean of a specific column in a DataFrame?
import pandas as pd
l = [1,2,3,4]
df = pd.DataFrame(l)
df.mean(0)

#3.  Create a scatter plot using Matplotlib?
import matplotlib.pyplot as plt
x= [1,2,3,4,5]
y= [6,7,8,9,10]
plt.scatter(x,y)
plt.show()

#4.  How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap?
import seaborn as sns
df = sns.load_dataset('iris')
corr_matrix = df.corr(numeric_only=True)
sns.heatmap(corr_matrix)

#5.  Generate a bar plot using Plotly?
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Bar(x = [1,2,3,4,5], y= [3,8,5,2,6]))

#6.  Create a DataFrame and add a new column based on an existing column
import pandas as pd
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df['C'] = df['A'] + df['B']
df

#7.  Write a program to perform element-wise multiplication of two NumPy arrays
import numpy as np
a= np.array([1,2,3])
b= np.array([4,5,6])
a*b # element wise multiplication
a@b # matrix multiplication

#8.  Create a line plot with multiple lines using Matplotlib
import matplotlib.pyplot as plt
x = [1,2,3,4]
y1 = [5,6,7,8]
y2 = [9,10,11,12]
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

#10.  Create a histogram using Seaborn to visualize a distribution
import seaborn as sns
df = sns.load_dataset('tips')
sns.histplot(df['total_bill'])

#11.  Perform matrix multiplication using NumPy
import numpy as np
a = np.array([[1,2],
             [3,4]])
b = np.array([[5,6],
             [7,8]])
a@b

#12.  Use Pandas to load a CSV file and display its first 5 rows
import pandas as pd
df = pd.read_csv("https://gist.githubusercontent.com/kevin336/acbb2271e66c10a5b73aacf82ca82784/raw/e38afe62e088394d61ed30884dd50a6826eee0a8/employees.csv", header = None)
df
df.head()

#13.  A Create a 3D scatter plot using Plotly.
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter3d (x = [1,2,3,4,5], y = [3,8,5,2,6], z = [1,2,7,3,5]))
# Out:
# [ 6 13]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
